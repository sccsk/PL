# %%
import pandas as pd

# read csv file
all = pd.read_csv("tc.all.csv")
tc = pd.read_csv("tc24.csv")

# %%
all .head()
# Out:
#      醫院名稱            開業證號   區域       醫院地址         醫院電話  \
# 0  鑫鑫動物醫院  中市獸醫開字第105041號   中區  中華路一段112號  04-22254169
# 1  安生動物醫院  中市獸醫開字第105139號  太平區    新興路219號  04-23955466
# 2   仁愛犬醫院  中市獸醫開字第105078號   東區    進化路122號  04-22126987
# 3  富台動物醫院  中市獸醫開字第105185號   東區    練武路244號  04-22114331
# 4  東大動物醫院  中市獸醫開字第105063號   東區     信義街43號  04-22204161
#
#                                                業務類別          門診時間
# 0                  合法動物醫院,委辦寵物登記,特約狂犬病預防注射,委辦寵物絕育手術           NaN
# 1  合法動物醫院,委辦寵物登記,特約狂犬病預防注射,委辦寵物絕育手術,委辦急難救助,委辦動物中途收容           NaN
# 2  合法動物醫院,委辦寵物登記,特約狂犬病預防注射,委辦寵物絕育手術,委辦急難救助,委辦動物中途收容  21時至24時急診需預約
# 3                           合法動物醫院,委辦寵物登記,特約狂犬病預防注射           NaN
# 4         合法動物醫院,委辦寵物登記,特約狂犬病預防注射,委辦寵物絕育手術,委辦動物中途收容           NaN

# %%
tc .tail()
# Out:
#          醫院名稱   區域          醫院地址                     醫院電話  \
# 5      濟生動物醫院  北屯區   北平路3段75-12號  04-22385886 04-22384995
# 6      永昌動物醫院  北屯區        北屯路32號              04-22356236
# 7      康德動物醫院  北屯區     崇德路二段270號              04-22412700
# 8  慈愛動物醫院中港分院  大里區     國光路二段539號              04-24066688
# 9      成大動物醫院  清水區  臨港路五段658巷27號              0908-198108
#
#                      急診服務                                              業務類別
# 5         24小時急診服務，先電話預約。                                  合法動物醫院,特約狂犬病預防注射
# 6  夜間急診服務，週一至日21:00~22:00  合法動物醫院,委辦寵物登記,特約狂犬病預防注射,委辦寵物絕育手術,委辦急難救助,委辦動物中途收容
# 7                  24小時急診                                            合法動物醫院
# 8                  24小時急診                  合法動物醫院,委辦寵物登記,特約狂犬病預防注射,委辦寵物絕育手術
# 9            21:00~6:00急診                  合法動物醫院,委辦寵物登記,特約狂犬病預防注射,委辦寵物絕育手術

# %%
s1=set(all["醫院名稱"])
s2=set(tc["醫院名稱"])

# %%
s1
# Out:
# {'?擎獸醫院',
#  '?莫動物醫院',
#  'ㄚ貓ㄚ狗動物醫院',
#  '一心獸醫院',
#  '三三動物診所',
#  '上群動物醫院',
#  '中一動物醫院',
#  '中台動物醫院',
#  '中山動物醫院',
#  '中山犬醫院',
#  '中心動物醫院',
#  '中泰動物醫院',
#  '中科動物醫院',
#  '中美獸醫院',
#  '中華動物醫院',
#  '中華動物醫院清水分院',
#  '中華愛犬醫院',
#  '五權動物醫院',
#  '五福動物醫院',
#  '亞東動物醫院',
#  '人人動物醫院',
#  '人愛動物醫院',
#  '仁愛犬醫院',
#  '佑全動物醫院',
#  '佑晟動物醫院',
#  '何康動物醫院',
#  '佳佳動物醫院',
#  '佳恩動物醫院',
#  '佳群動物醫院',
#  '侏儸紀野生動物專科醫院',
#  '信安動物醫院',
#  '信揚動物醫院',
#  '健康動物醫院',
#  '健生動物醫院',
#  '傳騏動物醫院',
#  '光佑動物醫院',
#  '光正獸醫院',
#  '全國動物醫院',
#  '全國動物醫院七期分院',
#  '全國動物醫院中科分院',
#  '全國動物醫院北全分院',
#  '全國動物醫院大里分院',
#  '全國動物醫院大雅分院',
#  '全國動物醫院精業分院',
#  '全國動物醫院豐原分院',
#  '全國貓醫院',
#  '全科動物醫院',
#  '全邑動物醫院',
#  '六順動物醫院',
#  '冠生動物醫院',
#  '凡賽爾賽鴿動物醫院',
#  '凱特森貓專科醫院',
#  '劍橋動物醫院',
#  '劍橋動物醫院北屯分院',
#  '加諾動物醫院',
#  '協和動物醫院',
#  '可安動物醫院',
#  '可米動物醫院',
#  '台大動物醫院',
#  '台灣動物醫院',
#  '台灣福懋毛公館動物醫院',
#  '台碩動物醫院',
#  '吉田動物醫院',
#  '吉米哈利動物醫院',
#  '吉美動物醫院',
#  '名芯動物醫院',
#  '名鼎動物醫院',
#  '品品動物醫院',
#  '哈囉彼得動物醫院',
#  '啟仁動物醫院',
#  '喬丹動物醫院',
#  '喵屋貓咪專科醫院',
# ...

# %%
s2
# Out:
# {'中台動物醫院',
#  '仁愛犬醫院',
#  '全國動物醫院',
#  '康德動物醫院',
#  '惠犬動物醫院',
#  '慈愛動物醫院中港分院',
#  '成大動物醫院',
#  '永昌動物醫院',
#  '濟生動物醫院',
#  '羅大宇動物醫院'}

# %%
print('臺中市動物醫院且提供夜間急診或24小時營業動物醫院')
print(s1&s2)
# Out:
# 臺中市動物醫院且提供夜間急診或24小時營業動物醫院
# {'慈愛動物醫院中港分院', '濟生動物醫院', '康德動物醫院', '永昌動物醫院', '中台動物醫院', '成大動物醫院', '仁愛犬醫院', '羅大宇動物醫院', '全國動物醫院', '惠犬動物醫院'}

# %%
print('臺中市所有動物醫院')
print(s1|s2)
# Out:
# 臺中市所有動物醫院
# ...

# %%
print('臺中市動物醫院但沒有提供夜間急診或24小時營業動物醫院')
print(s1-s2)
# Out:
# 臺中市動物醫院但沒有提供夜間急診或24小時營業動物醫院
# ...

# %%
print('臺中市動物醫院但沒有提供夜間急診或24小時營業動物醫院及有提供夜間急診或24小時營業動物醫院')
print(s1^s2)
# Out:
# 臺中市動物醫院但沒有提供夜間急診或24小時營業動物醫院及有提供夜間急診或24小時營業動物醫院
# ...
