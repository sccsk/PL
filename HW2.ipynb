# %%
d={
    '新竹市立動物園110年度門票收入及入園人數':[
  {
    "年度": "110",
    "月份": "1月",
    "現金門票收入": "1857165",
    "多卡通門票收入": "1346110",
    "門票收入合計": "3203275",
    "當月購票入園人數": "94118"
  },
  {
    "年度": "110",
    "月份": "2月",
    "現金門票收入": "2530235",
    "多卡通門票收入": "2052085",
    "門票收入合計": "4582320",
    "當月購票入園人數": "121185"
  },
  {
    "年度": "110",
    "月份": "3月",
    "現金門票收入": "1518800",
    "多卡通門票收入": "1679845",
    "門票收入合計": "3198645",
    "當月購票入園人數": "106128"
  },
  {
    "年度": "110",
    "月份": "4月",
    "現金門票收入": "1679605",
    "多卡通門票收入": "1594210",
    "門票收入合計": "3273815",
    "當月購票入園人數": "139848"
  },
  {
    "年度": "110",
    "月份": "5月",
    "現金門票收入": "519755",
    "多卡通門票收入": "609585",
    "門票收入合計": "1129340",
    "當月購票入園人數": "41892"
  },
  {
    "年度": "110",
    "月份": "6月",
    "現金門票收入": "0",
    "多卡通門票收入": "0",
    "門票收入合計": "0",
    "當月購票入園人數": "0"
  },
  {
    "年度": "110",
    "月份": "7月",
    "現金門票收入": "64640",
    "多卡通門票收入": "77830",
    "門票收入合計": "142470",
    "當月購票入園人數": "5170"
  },
  {
    "年度": "110",
    "月份": "8月",
    "現金門票收入": "885025",
    "多卡通門票收入": "894865",
    "門票收入合計": "1779890",
    "當月購票入園人數": "67901"
  },
  {
    "年度": "110",
    "月份": "9月",
    "現金門票收入": "849690",
    "多卡通門票收入": "815385",
    "門票收入合計": "1665057",
    "當月購票入園人數": "68908"
  },
  {
    "年度": "110",
    "月份": "10月",
    "現金門票收入": "880255",
    "多卡通門票收入": "868330",
    "門票收入合計": "1748585",
    "當月購票入園人數": "99629"
  },
  {
    "年度": "110",
    "月份": "11月",
    "現金門票收入": "1414345",
    "多卡通門票收入": "1438290",
    "門票收入合計": "2852635",
    "當月購票入園人數": "102500"
  },
  {
    "年度": "110",
    "月份": "12月",
    "現金門票收入": "1288450",
    "多卡通門票收入": "1006940",
    "門票收入合計": "2295390",
    "當月購票入園人數": "102969"
  }
]}

# %%
#將d裡面的內容(items)顯示出來
d.items()
# Out:
# dict_items([('新竹市立動物園110年度門票收入及入園人數', [{'年度': '110', '月份': '1月', '現金門票收入': '1857165', '多卡通門票收入': '1346110', '門票收入合計': '3203275', '當月購票入園人數': '94118'}, {'年度': '110', '月份': '2月', '現金門票收入': '2530235', '多卡通門票收入': '2052085', '門票收入合計': '4582320', '當月購票入園人數': '121185'}, {'年度': '110', '月份': '3月', '現金門票收入': '1518800', '多卡通門票收入': '1679845', '門票收入合計': '3198645', '當月購票入園人數': '106128'}, {'年度': '110', '月份': '4月', '現金門票收入': '1679605', '多卡通門票收入': '1594210', '門票收入合計': '3273815', '當月購票入園人數': '139848'}, {'年度': '110', '月份': '5月', '現金門票收入': '519755', '多卡通門票收入': '609585', '門票收入合計': '1129340', '當月購票入園人數': '41892'}, {'年度': '110', '月份': '6月', '現金門票收入': '0', '多卡通門票收入': '0', '門票收入合計': '0', '當月購票入園人數': '0'}, {'年度': '110', '月份': '7月', '現金門票收入': '64640', '多卡通門票收入': '77830', '門票收入合計': '142470', '當月購票入園人數': '5170'}, {'年度': '110', '月份': '8月', '現金門票收入': '885025', '多卡通門票收入': '894865', '門票收入合計': '1779890', '當月購票入園人數': '67901'}, {'年度': '110', '月份': '9月', '現金門票收入': '849690', '多卡通門票收入': '815385', '門票收入合計': '1665057', '當月購
# ...

# %%
d.keys()
# Out:
# dict_keys(['新竹市立動物園110年度門票收入及入園人數'])

# %%
ask = "1月"

# %%
for i in d:
    if ask == i.get('月份'):
        print(ask, '的', i.get('當月購票入園人數'), '人')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
#       1 for i in d:
# ----> 2     if ask == i.get('月份'):
#       3         print(ask, '的', i.get('當月購票入園人數'), '人')
#
# AttributeError: 'str' object has no attribute 'get'
