# %%
import json

# %%
test = open('ppl.json',encoding="utf8")
Data = json.load(test)
type(Data)
# Out:
# dict

# %%
#將d裡面的內容(items)顯示出來
Data.items()
# Out:
# dict_items([('入園人數', [{'年度': '110', '月份': '1月', '現金門票收入': '1857165', '多卡通門票收入': '1346110', '門票收入合計': '3203275', '當月購票入園人數': '94118'}, {'年度': '110', '月份': '2月', '現金門票收入': '2530235', '多卡通門票收入': '2052085', '門票收入合計': '4582320', '當月購票入園人數': '121185'}, {'年度': '110', '月份': '3月', '現金門票收入': '1518800', '多卡通門票收入': '1679845', '門票收入合計': '3198645', '當月購票入園人數': '106128'}, {'年度': '110', '月份': '4月', '現金門票收入': '1679605', '多卡通門票收入': '1594210', '門票收入合計': '3273815', '當月購票入園人數': '139848'}, {'年度': '110', '月份': '5月', '現金門票收入': '519755', '多卡通門票收入': '609585', '門票收入合計': '1129340', '當月購票入園人數': '41892'}, {'年度': '110', '月份': '6月', '現金門票收入': '0', '多卡通門票收入': '0', '門票收入合計': '0', '當月購票入園人數': '0'}, {'年度': '110', '月份': '7月', '現金門票收入': '64640', '多卡通門票收入': '77830', '門票收入合計': '142470', '當月購票入園人數': '5170'}, {'年度': '110', '月份': '8月', '現金門票收入': '885025', '多卡通門票收入': '894865', '門票收入合計': '1779890', '當月購票入園人數': '67901'}, {'年度': '110', '月份': '9月', '現金門票收入': '849690', '多卡通門票收入': '815385', '門票收入合計': '1665057', '當月購票入園人數': '68908'},
# ...

# %%
temp = Data.get('入園人數')
temp
# Out:
# [{'年度': '110',
#   '月份': '1月',
#   '現金門票收入': '1857165',
#   '多卡通門票收入': '1346110',
#   '門票收入合計': '3203275',
#   '當月購票入園人數': '94118'},
#  {'年度': '110',
#   '月份': '2月',
#   '現金門票收入': '2530235',
#   '多卡通門票收入': '2052085',
#   '門票收入合計': '4582320',
#   '當月購票入園人數': '121185'},
#  {'年度': '110',
#   '月份': '3月',
#   '現金門票收入': '1518800',
#   '多卡通門票收入': '1679845',
#   '門票收入合計': '3198645',
#   '當月購票入園人數': '106128'},
#  {'年度': '110',
#   '月份': '4月',
#   '現金門票收入': '1679605',
#   '多卡通門票收入': '1594210',
#   '門票收入合計': '3273815',
#   '當月購票入園人數': '139848'},
#  {'年度': '110',
#   '月份': '5月',
#   '現金門票收入': '519755',
#   '多卡通門票收入': '609585',
#   '門票收入合計': '1129340',
#   '當月購票入園人數': '41892'},
#  {'年度': '110',
#   '月份': '6月',
#   '現金門票收入': '0',
#   '多卡通門票收入': '0',
#   '門票收入合計': '0',
#   '當月購票入園人數': '0'},
#  {'年度': '110',
#   '月份': '7月',
#   '現金門票收入': '64640',
#   '多卡通門票收入': '77830',
#   '門票收入合計': '142470',
#   '當月購票入園人數': '5170'},
#  {'年度': '110',
#   '月份': '8月',
#   '現金門票收入': '885025',
#   '多卡通門票收入': '894865',
# ...

# %%
ask = "1月"

# %%
for i in temp:
    if ask == i.get('月份'):
        print(ask,'入園人數',i.get('當月購票入園人數'), '人')
# Out:
# 1月 入園人數 94118 人

# %%
allage = []
for i in temp:
    allage.append(i.get('當月購票入園人數'))
allage
# Out:
# ['94118',
#  '121185',
#  '106128',
#  '139848',
#  '41892',
#  '0',
#  '5170',
#  '67901',
#  '68908',
#  '99629',
#  '102500',
#  '102969']
