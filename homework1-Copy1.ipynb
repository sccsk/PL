# %%
import pandas as pd

# read csv file
df = pd.read_csv("k1.csv")

# %%
df.tail()
# Out:
#           代碼               學校名稱 公/私立     縣市名稱 鄉鎮市區名稱                   地址  \
# 6837  724X01   連江縣立介壽國民中小學附設幼兒園   公立  [72]連江縣    南竿鄉  [209]連江縣南竿鄉介壽村1鄰13號
# 6838  724X02  連江縣北竿鄉塘岐國民小學附設幼兒園   公立  [72]連江縣    北竿鄉  [210]連江縣北竿鄉塘岐村2鄰56號
# 6839  724X03   連江縣立敬恆國民中小學附設幼兒園   公立  [72]連江縣    莒光鄉  [211]連江縣莒光鄉青帆村2鄰19號
# 6840  724X04  連江縣莒光鄉東莒國民小學附設幼兒園   公立  [72]連江縣    莒光鄉   [211]連江縣莒光鄉大坪村1鄰4號
# 6841  724X05   連江縣立東引國民中小學附設幼兒園   公立  [72]連江縣    東引鄉  [212]連江縣東引鄉中柳村4鄰94號
#
#                    電話
# 6837  (08)3622192#181
# 6838  (083)655420#601
# 6839  (0836)88179#302
# 6840  (0836)89043#507
# 6841  (0836)77213#401

# %%
s1=df[ (df["縣市名稱"] == "[01]新北市") & (df["公/私立"] == "公立") ]

# %%
s2=df[ (df["縣市名稱"] == "[01]新北市") & (df["公/私立"] == "私立") ]

# %%
filt = (df["縣市名稱"] == "[01]新北市")
print(filt)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 6837    False
# 6838    False
# 6839    False
# 6840    False
# 6841    False
# Name: 縣市名稱, Length: 6842, dtype: bool

# %%
df[ (df["縣市名稱"] == "[01]新北市") & (df["公/私立"] == "公立") ]
# Out:
#           代碼               學校名稱 公/私立     縣市名稱 鄉鎮市區名稱  \
# 836   013K01  新北市新店區大豐國民小學附設幼兒園   公立  [01]新北市    新店區
# 837   013K02  新北市新店區雙城國民小學附設幼兒園   公立  [01]新北市    新店區
# 838   013K03  新北市林口區嘉寶國民小學附設幼兒園   公立  [01]新北市    林口區
# 839   013K04  新北市淡水區育英國民小學附設幼兒園   公立  [01]新北市    淡水區
# 840   013K05  新北市萬里區大坪國民小學附設幼兒園   公立  [01]新北市    萬里區
# ...      ...                ...  ...      ...    ...
# 1119  014Z03   新北市立青山國民中小學附設幼兒園   公立  [01]新北市    汐止區
# 1120  014Z04  新北市三峽區大埔國民小學附設幼兒園   公立  [01]新北市    三峽區
# 1121  014Z05  新北市新店區北新國民小學附設幼兒園   公立  [01]新北市    新店區
# 1122  014Z06  新北市林口區瑞平國民小學附設幼兒園   公立  [01]新北市    林口區
# 1123  014Z07  新北市蘆洲區忠義國民小學附設幼兒園   公立  [01]新北市    蘆洲區
#
#                               地址                電話
# 836     [231]新北市新店區大豐里17鄰民族路108號   (02)22190159#21
# 837   [231]新北市新店區雙城里11鄰安康路3段322號  (02)22156511#310
# 838       [244]新北市林口區嘉寶里1鄰嘉寶里22號  (02)26052716#860
# 839        [251]新北市淡水區埤島里4鄰埤頭14號  (02)26214390#114
# 840       [207]新北市萬里區雙興里13鄰大坪路1號   (02)24929461#71
# ...

# %%
# Out:
# list['學校名稱']
